# %% [markdown]
# # Exploration Methods
# When you receive a CSV file from an external source, you'll want to get a feel for the data.
#
# Let's import some data and then learn how to explore it.

# %%
# Setup
import os
import pandas as pd

# We use os.path.join because Windows uses a back slash (\) to separate directories
# while others use a forward slash (/)
users_file_name = os.path.join('data', 'users.csv')
users_file_name
# Out:
# 'data/users.csv'

# %% [markdown]
# ## CSV File Exploration
# If you want to take a peek at your CSV file, you could open it in an editor.
#
# Let's just use some standard Python to see the first couple lines of the file.

# %%
# Open the file and print out the first 5 lines
with open(users_file_name) as f:
    for i, line in enumerate(f.readlines()):
        print(line)
        if i==4: #python starts to count on 0
            break
# Out:
# ,first_name,last_name,email,email_verified,signup_date,referral_count,balance
#
# aaron,Aaron,Davis,aaron6348@gmail.com,True,2018-08-31,6,18.14
#
# acook,Anthony,Cook,cook@gmail.com,True,2018-05-12,2,55.45
#
# adam.saunders,Adam,Saunders,adam@gmail.com,False,2018-05-29,3,72.12
#
# adrian,Adrian,Fang,adrian.fang@teamtreehouse.com,True,2018-04-28,3,30.01

# %% [markdown]
# It is possible to access the bash behind the scenes directly from the notebook adding `!`: this only works for linux/mac users.
# For windows it is needed to install [cygwin](https://www.cygwin.com/). It is a collection of linux commands
# or one can use the native windows commands like `more`, `dir`, etc

# %%
! head -n 5 data/users.csv
# Out:
# ,first_name,last_name,email,email_verified,signup_date,referral_count,balance
# aaron,Aaron,Davis,aaron6348@gmail.com,True,2018-08-31,6,18.14
# acook,Anthony,Cook,cook@gmail.com,True,2018-05-12,2,55.45
# adam.saunders,Adam,Saunders,adam@gmail.com,False,2018-05-29,3,72.12
# adrian,Adrian,Fang,adrian.fang@teamtreehouse.com,True,2018-04-28,3,30.01

# %% [markdown]
# Notice how the first line is a header row. It has column names in it. By default, it will be assumed that the first row is your header row. Also, noticed that is `,` separated.
#
# Also note how the first column of that header row is empty...the values below in that first column appear to be usernames.  They are what we want for the index.
#
# We can use the `index_col` parameter of the `pandas.read_csv` function.

# %%
# Create a new `DataFrame` and set the index to the first column
users = pd.read_csv(users_file_name, index_col=0, sep=',')

# %% [markdown]
# ## Explore your imported DataFrame

# %% [markdown]
# A quick way to check and see if you got your CSV file read correctly is to use the [`DataFrame.head`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html) method. This gives you the first **x** number of rows. The head method, by default, returns 5 records. You can specify the number you want as the first argument, for instance `users.head(10)` will return the first 10 rows.

# %%
users.head()
# Out:
#               first_name last_name                          email  \
# aaron              Aaron     Davis            aaron6348@gmail.com
# acook            Anthony      Cook                 cook@gmail.com
# adam.saunders       Adam  Saunders                 adam@gmail.com
# adrian            Adrian      Fang  adrian.fang@teamtreehouse.com
# adrian.blair      Adrian     Blair           adrian9335@gmail.com
#
#                email_verified signup_date  referral_count  balance
# aaron                    True  2018-08-31               6    18.14
# acook                    True  2018-05-12               2    55.45
# adam.saunders           False  2018-05-29               3    72.12
# adrian                   True  2018-04-28               3    30.01
# adrian.blair             True  2018-06-16               7    25.85

# %% [markdown]
# Nice! We got it.  So let's see how many rows we have.  There are a couple of ways.

# %%
# Pythonic approach still works
len(users)
# Out:
# 475

# %% [markdown]
# The `DataFrame.shape` property works just like `np.array.shape` does. This is the length of each axis of your data frame, rows and columns.

# %%
users.shape
# Out:
# (475, 7)

# %% [markdown]
# ### Exploring

# %% [markdown]
# #### Counts

# %% [markdown]
# The [`DataFrame.count`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.count.html) method will count up each column for how many non-empty values we have.

# %%
users.count()
# Out:
# first_name        475
# last_name         430
# email             475
# email_verified    475
# signup_date       475
# referral_count    475
# balance           475
# dtype: int64

# %% [markdown]
# Most of our columns include values for each row, but looks like **last_name** has some missing ones.  The missing data will show up as `np.nan` -- NumPy's not a number -- in those records.
#
#
# The `count` method is data missing aware.

# %% [markdown]
# Remember that a `DataFrame` has the ability to contain multiple data types or [`dtypes`](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes).
#
# You can use the `DataFrame.dtypes` to see the `dtype` of each column.

# %% [markdown]
# #### Data types

# %%
users.dtypes
# Out:
# first_name         object
# last_name          object
# email              object
# email_verified       bool
# signup_date        object
# referral_count      int64
# balance           float64
# dtype: object

# %% [markdown]
# As you can see, most of the data types of these columns were inferred, or assumed, correctly.  See how automatically **`email_verified`** is `bool`, **`referral_count`** is an integer, and **`balance`** a float. This happened when we used `pd.read_csv`.
#
# One thing to note though that the **`signup_date`** field is an `object` and not a `datetime`. You can convert these during or after import if you need to or it is possible to convert using:

# %%
users['signup_date'] = pd.to_datetime(users.signup_date, format='%Y-%m-%d')

# %%
users.dtypes
# Out:
# first_name                object
# last_name                 object
# email                     object
# email_verified              bool
# signup_date       datetime64[ns]
# referral_count             int64
# balance                  float64
# dtype: object

# %% [markdown]
# #### Describe your data
# The [`DataFrame.describe`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html) method is a great way to get a vibe for all numeric data in your `DataFrame`.  You'll notice only columns that have numeric data are returned, and ones with booleans or text, like **`email_verified`** and **`first_name`** are left out.
#
#
# You'll see lots of different aggregations.

# %%
users.describe()
# Out:
#        referral_count     balance
# count      475.000000  475.000000
# mean         3.429474   49.933263
# std          2.281085   28.280448
# min          0.000000    0.050000
# 25%          2.000000   25.305000
# 50%          3.000000   51.570000
# 75%          5.000000   74.480000
# max          7.000000   99.900000

# %% [markdown]
# Most of these aggregations are available by themselves as well

# %%
# The mean or average
users.mean()
# Out:
# email_verified     0.818947
# referral_count     3.429474
# balance           49.933263
# dtype: float64

# %%
# Standard deviation
users.std()
# Out:
# email_verified     0.385468
# referral_count     2.281085
# balance           28.280448
# dtype: float64

# %%
# The minimum of each column
users.min()
# Out:
# first_name                       Aaron
# email             aalvarez@hotmail.com
# email_verified                   False
# signup_date        2018-01-01 00:00:00
# referral_count                       0
# balance                           0.05
# dtype: object

# %%
# The maximum of each column
users.max()
# Out:
# first_name                    Zachary
# email                 zneal@gmail.com
# email_verified                   True
# signup_date       2018-09-25 00:00:00
# referral_count                      7
# balance                          99.9
# dtype: object

# %% [markdown]
# Since columns are in reality a `Series` you can quickly access their counts of different values using the [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) method.

# %%
users.email_verified.value_counts()
# Out:
# True     389
# False     86
# Name: email_verified, dtype: int64

# %% [markdown]
# By default the value counts are sorted descending, so the most frequent are at top.

# %%
# Most common first name
users.first_name.value_counts().head()
# Out:
# Mark       11
# David      10
# Michael     9
# Emily       7
# Joshua      7
# Name: first_name, dtype: int64

# %% [markdown]
# ### Rearranging your data
# You can create a new `DataFrame` that is sorted by using the [`sort_values`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html) method.
#
# Let's sort the DataFrame so that the user with the highest **`balance`** is at the top. By default, ascending order is assumed, you can change that by setting the `ascending` keyword argument to `False`.

# %%
users.sort_values(by='balance', ascending=False).head(15)
# Out:
#                first_name last_name                    email  email_verified  \
# twhite            Timothy     White    white5136@hotmail.com            True
# karen.snow          Karen      Snow          ksnow@yahoo.com            True
# king                Billy      King   billy.king@hotmail.com            True
# king3246         Brittney      King       brittney@yahoo.com            True
# crane203          Valerie     Crane  valerie7051@hotmail.com            True
# paul6364             Paul      Hill     paul2980@hotmail.com            True
# thompson2327         Troy  Thompson  troy.thompson@gmail.com           False
# sbennett           Steven   Bennett       sbennett@yahoo.com            True
# clayton6074        Robert   Clayton         robert@gmail.com            True
# christopher   Christopher       NaN    christopher@gmail.com            True
# peter               Peter    Grimes        pgrimes@yahoo.com            True
# margaret265      Margaret       NaN       margaret@gmail.com            True
# jacob.davis         Jacob     Davis         jdavis@gmail.com           False
# joseph2431         Joseph    Harris         joseph@gmail.com            True
# eugene4448         Eugene       NaN         eugene@gmail.com            True
#
#              signup_date  referral_count  balance
# twhite        2018-07-06               5    99.90
# karen.snow    2018-05-06               2    99.38
# king          2018-05-29               4    98.80
# king3246      2018-04-15               6    98.79
# crane203      2018-05-12               3    98.69
# paul6364      2018-02-28               1    98.62
# thompson2327  2018-04-24               7    98.09
# sbennett      2018-02-07               5    97.38
# clayton6074   2018-01-12               7    97.05
# christopher   2018-07-24               3    96.96
# peter         2018-09-02               0    96.79
# margaret265   2018-01-05               1    96.14
# jacob.davis   2018-09-16               0    95.70
# joseph2431    2018-03-07               5    95.47
# eugene4448    2018-06-08               0    95.38

# %% [markdown]
# You'll notice that `sort_values` call actually created a new `DataFrame`. If you want to permanently change the sort from the default (sorted by index), you can pass `True` as an argument to the `inplace` keyword parameter.

# %%
# Sort first by last_name and then first_name. By default, np.nan show up at the end
users.sort_values(by=['last_name', 'first_name'], inplace=True)
# Sort order is now changed
users.head()
# Out:
#               first_name last_name                       email  \
# darlene.adams    Darlene     Adams           adams@hotmail.com
# lauren            Lauren   Aguilar  lauren.aguilar@summers.com
# daniel            Daniel     Allen           allen@hotmail.com
# kallen             Kathy     Allen           kathy@hotmail.com
# alvarado          Denise  Alvarado        alvarado@hotmail.com
#
#                email_verified signup_date  referral_count  balance
# darlene.adams            True  2018-09-15               2    67.02
# lauren                  False  2018-05-31               4    69.90
# daniel                  False  2018-07-01               2    21.21
# kallen                  False  2018-02-20               1    43.72
# alvarado                 True  2018-09-07               6    26.72

# %% [markdown]
# And if you want to sort by the index, like it was originally, you can use the `sort_index` method.

# %%
users.sort_index(inplace=True)
users.head()
# Out:
#               first_name last_name                          email  \
# aaron              Aaron     Davis            aaron6348@gmail.com
# acook            Anthony      Cook                 cook@gmail.com
# adam.saunders       Adam  Saunders                 adam@gmail.com
# adrian            Adrian      Fang  adrian.fang@teamtreehouse.com
# adrian.blair      Adrian     Blair           adrian9335@gmail.com
#
#                email_verified signup_date  referral_count  balance
# aaron                    True  2018-08-31               6    18.14
# acook                    True  2018-05-12               2    55.45
# adam.saunders           False  2018-05-29               3    72.12
# adrian                   True  2018-04-28               3    30.01
# adrian.blair             True  2018-06-16               7    25.85

# %% [markdown]
# we can change the index.

# %%
users.reset_index(inplace=True)

# %%
users.head()
# Out:
#            index first_name last_name                          email  \
# 0          aaron      Aaron     Davis            aaron6348@gmail.com
# 1          acook    Anthony      Cook                 cook@gmail.com
# 2  adam.saunders       Adam  Saunders                 adam@gmail.com
# 3         adrian     Adrian      Fang  adrian.fang@teamtreehouse.com
# 4   adrian.blair     Adrian     Blair           adrian9335@gmail.com
#
#    email_verified signup_date  referral_count  balance
# 0            True  2018-08-31               6    18.14
# 1            True  2018-05-12               2    55.45
# 2           False  2018-05-29               3    72.12
# 3            True  2018-04-28               3    30.01
# 4            True  2018-06-16               7    25.85

# %% [markdown]
# note that it was created a columns named `index`. We can rename that column:

# %%
users.rename(columns={'index':'user_name'}, inplace=True)

# %%
users.head()
# Out:
#        user_name first_name last_name                          email  \
# 0          aaron      Aaron     Davis            aaron6348@gmail.com
# 1          acook    Anthony      Cook                 cook@gmail.com
# 2  adam.saunders       Adam  Saunders                 adam@gmail.com
# 3         adrian     Adrian      Fang  adrian.fang@teamtreehouse.com
# 4   adrian.blair     Adrian     Blair           adrian9335@gmail.com
#
#    email_verified signup_date  referral_count  balance
# 0            True  2018-08-31               6    18.14
# 1            True  2018-05-12               2    55.45
# 2           False  2018-05-29               3    72.12
# 3            True  2018-04-28               3    30.01
# 4            True  2018-06-16               7    25.85

# %%
## Datetime

# %%
users.dtypes
# Out:
# user_name                 object
# first_name                object
# last_name                 object
# email                     object
# email_verified              bool
# signup_date       datetime64[ns]
# referral_count             int64
# balance                  float64
# dtype: object

# %%
users.head()
# Out:
#        user_name first_name last_name                          email  \
# 0          aaron      Aaron     Davis            aaron6348@gmail.com
# 1          acook    Anthony      Cook                 cook@gmail.com
# 2  adam.saunders       Adam  Saunders                 adam@gmail.com
# 3         adrian     Adrian      Fang  adrian.fang@teamtreehouse.com
# 4   adrian.blair     Adrian     Blair           adrian9335@gmail.com
#
#    email_verified signup_date  referral_count  balance
# 0            True  2018-08-31               6    18.14
# 1            True  2018-05-12               2    55.45
# 2           False  2018-05-29               3    72.12
# 3            True  2018-04-28               3    30.01
# 4            True  2018-06-16               7    25.85

# %%
#add one day to all the dates. 
(users['signup_date'] + pd.Timedelta(1, unit='d')).head()
# Out:
# 0   2018-09-01
# 1   2018-05-13
# 2   2018-05-30
# 3   2018-04-29
# 4   2018-06-17
# Name: signup_date, dtype: datetime64[ns]

# %%
#add one month to all the dates. 
(users['signup_date'] + pd.Timedelta(1, unit='M')).head()
# Out:
# 0   2018-09-30 10:29:06
# 1   2018-06-11 10:29:06
# 2   2018-06-28 10:29:06
# 3   2018-05-28 10:29:06
# 4   2018-07-16 10:29:06
# Name: signup_date, dtype: datetime64[ns]

# %%
#Subtracting dates:
(users['signup_date'] -pd.to_datetime('2019-12-25T01:01:03',) ).head()
# Out:
# 0   -482 days +22:58:57
# 1   -593 days +22:58:57
# 2   -576 days +22:58:57
# 3   -607 days +22:58:57
# 4   -558 days +22:58:57
# Name: signup_date, dtype: timedelta64[ns]

# %%
#look ups useing date
(users['signup_date'].dt.month < 4).sum()
# Out:
# 157

# %%
users[users['signup_date'].dt.month==1]
# Out:
#              user_name first_name    last_name                         email  \
# 12             andrade    Melissa      Andrade            mandrade@yahoo.com
# 23            arosario     Amanda      Rosario              amanda@yahoo.com
# 26           austin486     Austin         Ward              ward@hotmail.com
# 34         blankenship      April  Blankenship       blankenship11@gmail.com
# 45            brett643      Brett      Sanchez       sanchez4831@hotmail.com
# 57        campbell1062      Amber     Campbell      amber.campbell@gmail.com
# 73           clark8139       Tara        Clark               clark@gmail.com
# 74         clayton6074     Robert      Clayton              robert@gmail.com
# 85           cross9059      Emily        Cross           emily8281@gmail.com
# 99           david5498      David       Garcia         david2998@hotmail.com
# 102          davis9792      David        Davis         davis3883@hotmail.com
# 106           dean2365      Brian         Dean          dean3892@hotmail.com
# 110           dedwards    Deborah      Edwards           deborah@hotmail.com
# 114              diana      Diana       Wagner          wagner8014@gmail.com
# 134        emily.lewis      Emily        Lewis           lewis8915@yahoo.com
# 141          fernandez    Theresa    Fernandez             theresa@gmail.com
# 159          grant1643        Jay        Grant         grant3970@hotmail.com
# 160           greg5920       Greg       Kelley            greg1612@gmail.com
# 161  gregory.blackwell    Gregory    Blackwell    gblackwell@frost-white.com
# 162       gregory.rios    Gregory         Rios             gregory@gmail.com
# 163        gregory7148        Jon      Gregory      gregory@keller-moran.net
# 185         holden4580      Jason       Holden              holden@gmail.com
# 192          jaime6887      Jaime      Johnson  johnson@garcia-contreras.org
# 197          jason7792      Jason      Holland          jholland@hotmail.com
# 203            jeffrey    Jeffrey      Stewart       stewart7222@hotmail.com
# 206   jennifer.hendrix   Jennifer      Hendrix         hendrix1706@gmail.com
# 229              jones       Erin        Jones          erin.jones@yahoo.com
# 235       joshua.henry     Joshua        Henry            joshua@hotmail.com
# 246          katherine  Katherine          NaN           katherine@yahoo.com
# 257           kimberly   Kimberly          NaN            kimberly@yahoo.com
# 269          lacey8987      Lacey         Ball           lacey5080@gmail.com
# 276           leah6255       Leah        Black          leah6754@willis.info
# 287               lowe     Albert         Lowe         albert.lowe@lopez.com
# 296        margaret265   Margaret          NaN            margaret@gmail.com
# 298               mark       Mark         Shaw            shaw4221@yahoo.com
# 310        matthew7940    Matthew        Smith            msmith@hotmail.com
# 317          medina891       Rose       Medina         rose.medina@wolfe.net
# 320    melissa.mendoza    Melissa      Mendoza         mendoza7698@yahoo.com
# 323            michael    Michael          NaN        michael952@hotmail.com
# 327       michelle4225   Michelle        Horne      michelle.horne@yahoo.com
# 378      rodriguez5768     Joshua    Rodriguez  joshua.rodriguez@hotmail.com
# 384         rose.eaton       Rose        Eaton              reaton@gmail.com
# 386              rsnow      Randy         Snow         randy5950@johnson.com
# 388               ruth       Ruth      Randall             randall@yahoo.com
# 391         samuel1489     Samuel    Dominguez              samuel@gmail.com
# 394         sandra2071     Sandra          NaN            sandra63@yahoo.com
# 413          smith9087   Kimberly        Smith          kimberly@hotmail.com
# 414             smoyer     Sydney        Moyer        sydney7488@hotmail.com
# 418           sstanton   Samantha      Stanton    samantha.stanton@gmail.com
# 421              stein    Douglas        Stein               stein@yahoo.com
# 432      tanya.carlson      Tanya      Carlson          tcarlson@hotmail.com
# 435         taylor2783     Taylor          NaN             taylor@lewis.info
# 450             torres     Taylor       Torres       taylor.torres@ware.info
# 463               west      Brian         West                west@yahoo.com
#
#      email_verified signup_date  referral_count  balance
# 12             True  2018-01-06               3    83.22
# 23             True  2018-01-29               1    76.19
# 26             True  2018-01-04               7     0.48
# 34             True  2018-01-12               3    48.31
# 45             True  2018-01-03               6    30.80
# 57             True  2018-01-10               3    35.66
# 73             True  2018-01-26               6    93.23
# 74             True  2018-01-12               7    97.05
# 85             True  2018-01-07               7    83.62
# 99             True  2018-01-05               4    29.14
# 102            True  2018-01-04               4    36.90
# 106            True  2018-01-08               6     8.50
# 110           False  2018-01-13               0    25.63
# 114            True  2018-01-15               4    19.45
# 134            True  2018-01-13               4    57.51
# 141            True  2018-01-13               5    47.13
# 159            True  2018-01-25               7     3.01
# 160            True  2018-01-02               6    29.16
# 161            True  2018-01-10               3    63.14
# 162            True  2018-01-13               4    16.42
# 163            True  2018-01-11               6    15.62
# 185            True  2018-01-17               3     7.95
# 192           False  2018-01-19               4    81.60
# 197           False  2018-01-18               0    22.37
# 203            True  2018-01-02               0    40.58
# 206            True  2018-01-15               0    37.20
# 229            True  2018-01-25               2    86.66
# 235            True  2018-01-05               2    80.03
# 246           False  2018-01-26               3    59.06
# 257           False  2018-01-06               5    54.73
# 269            True  2018-01-02               0    93.49
# 276            True  2018-01-13               1    43.67
# 287            True  2018-01-13               1    60.90
# 296            True  2018-01-05               1    96.14
# 298           False  2018-01-15               5     6.25
# 310            True  2018-01-27               4    73.55
# 317            True  2018-01-01               5    54.68
# 320            True  2018-01-18               2    72.05
# 323            True  2018-01-28               0    78.56
# 327            True  2018-01-15               0    65.03
# 378            True  2018-01-04               3    51.06
# 384            True  2018-01-21               7    90.03
# 386            True  2018-01-31               5    40.78
# 388           False  2018-01-28               0    70.39
# 391           False  2018-01-24               4    31.53
# 394            True  2018-01-18               1    45.22
# 413            True  2018-01-01               6    54.04
# 414            True  2018-01-03               2    90.87
# 418            True  2018-01-25               3    43.05
# 421           False  2018-01-02               1    48.52
# 432            True  2018-01-13               0    27.79
# 435            True  2018-01-07               1    11.19
# 450            True  2018-01-12               7    21.88
# 463            True  2018-01-30               3    52.83
